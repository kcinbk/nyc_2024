# %%
import requests
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)
pd.set_option("display.max_colwidth", None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


from requests.exceptions import ReadTimeout, HTTPError
import time
from time import sleep
from sodapy import Socrata

# %%
def get_opendata(dataset_identifier):
    client = Socrata("data.cityofnewyork.us", app_token=None)
    limit = 1000000
    offset = 0
    all_response = []

    max_retries = 5
    retry = 0

    while True:
        try:
            response = client.get(
                dataset_identifier = dataset_identifier, 
                limit=limit,
                offset=offset
            )
            if not response:
                break

            all_response.extend(response)
            offset += limit
            print(f"Working")
            retry = 0  # Reset retry after a successful request

        except Exception as e:
            retry += 1
            print(f"Retry No. {retry} due to error: {e}")
            time.sleep(2 * retry)  # Exponential backoff
            if retry > max_retries:
                print("Max retries reached. Failed")
                break
        
        print(f'Retrieved {len(all_response)} rows of data')
    return all_response

# %%
nycha_residential_address = "3ub5-4ph8"
nycha_residential_address_json = get_opendata(nycha_residential_address)

nycha_development_data_book = "evjd-dqpz"
nycha_development_data_book_json = get_opendata(nycha_development_data_book)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Working
# Retrieved 3054 rows of data
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Working
# Retrieved 346 rows of data

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 20)

# %%
df1 = pd.DataFrame(nycha_residential_address_json)
df2 = pd.DataFrame(nycha_development_data_book_json)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3054 entries, 0 to 3053
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   development                     3054 non-null   object
#  1   tds                             3054 non-null   object
#  2   building                        3054 non-null   object
#  3   stairhall_                      3054 non-null   object
#  4   borough                         3054 non-null   object
#  5   house                           3054 non-null   object
#  6   street                          3054 non-null   object
#  7   address                         3054 non-null   object
#  8   city                            3054 non-null   object
#  9   state                           3054 non-null   object
#  10  zip_code                        3054 non-null   object
#  11  bin                             3054 non-null   object
#  12  block                           3054 non-null   object
#  13  lot                             3054 non-null   object
#  14  borough_block_lot               3054 non-null   object
#  15  census_tract_2010               3054 non-null   object
#  16  neighborhood_tabulation_area    3054 non-null   object
#  17  neighborhood_tabulation_area_1  3054 non-null   object
#  18  community_district              3054 non-null   object
#  19  city_council_district           3054 non-null   object
#  20  state_assembly_district         3054 non-null   object
#  21  state_senate_district           3054 non-null   object
#  22  us_congressional_district       3054 non-null   object
#  23  latitude                        3054 non-null   object
#  24  longitude                       3054 non-null   object
#  25  privately_managed               99 non-null     object
# dtypes: object(26)
# memory usage: 620.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 52 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   data_as_of                                 346 non-null    object
#  1   development                                346 non-null    object
#  2   hud_amp_                                   343 non-null    object
#  3   tds_                                       344 non-null    object
#  4   consolidated_tds_                          340 non-null    object
#  5   development_edp_                           339 non-null    object
#  6   operating_edp_                             339 non-null    object
#  7   hud__                                      340 non-null    object
#  8   program                                    346 non-null    object
#  9   method                                     343 non-null    object
#  10  type                                       346 non-null    object
#  11  number_of_section_8_transition_apartments  259 non-null    object
#  12  number_of_current_apartments               344 non-null    object
#  13  total_number_of_apartments                 344 non-null    object
#  14  number_of_rental_rooms                     340 non-null    object
#  15  avg_no_r_r_per_apartment                   340 non-null    object
#  16  population_section_8_transition            309 non-null    object
#  17  population_public_housing                  338 non-null    object
#  18  total_population                           338 non-null    object
#  19  total_of_fixed_income_household            254 non-null    object
#  20  percent_fixed_income_households            254 non-null    object
#  21  number_of_residential_bldgs                344 non-null    object
#  22  number_of_non_residential_bldgs            341 non-null    object
#  23  number_of_stairhalls                       340 non-null    object
#  24  number_of_stories                          344 non-null    object
#  25  total_area_sq_ft                           344 non-null    object
#  26  acres                                      344 non-null    object
#  27  net_dev_area_sq_ft                         344 non-null    object
#  28  excluding_park_acres                       344 non-null    object
#  29  bldg_coverage_sq_ft                        329 non-null    object
#  30  cubage_cu_ft                               328 non-null    object
#  31  bldg_coverage__                            329 non-null    object
#  32  density                                    338 non-null    object
#  33  development_cost                           333 non-null    object
#  34  per_rental_room                            332 non-null    object
#  35  avg_monthly_gross_rent                     338 non-null    object
#  36  location_street_a                          346 non-null    object
#  37  location_street_b                          341 non-null    object
#  38  location_street_c                          322 non-null    object
#  39  location_street_d                          271 non-null    object
#  40  borough                                    346 non-null    object
#  41  community_distirct                         336 non-null    object
#  42  us_congressional_district                  346 non-null    object
#  43  ny_state_senate_district                   346 non-null    object
#  44  ny_state_assembly_district                 346 non-null    object
#  45  ny_city_council_district                   346 non-null    object
#  46  completion_date                            338 non-null    object
#  47  electricity_paid_by_residents              91 non-null     object
#  48  private_management                         33 non-null     object
#  49  federalized_development                    66 non-null     object
#  50  senior_development                         55 non-null     object
#  51  rad_transferred_date                       84 non-null     object
# dtypes: object(52)
# memory usage: 140.7+ KB

# %%
print(df1.development.nunique())
print(df2.development.nunique())
# Out:
# 242
# 346

# %%
columns_mask = df1.columns.str.lower().isin(df2.columns.str.lower())

df1.columns[columns_mask]
# Out:
# Index(['development', 'borough', 'us_congressional_district'], dtype='object')

# %%
pd.to_numeric(df2.total_population.str.replace(',','')).sum().astype(int)
# Out:
# 365353

# %%
df2 = df2[['development', 'total_population']]
df2.shape
# Out:
# (346, 2)

# %%
merged = df2.merge(df1, on='development', how='left')
merged = merged.drop_duplicates('development')
merged.shape
# Out:
# (346, 27)

# %%
merged.development.nunique()
# Out:
# 346

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 346 entries, 0 to 3157
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   development                     346 non-null    object
#  1   total_population                338 non-null    object
#  2   tds                             242 non-null    object
#  3   building                        242 non-null    object
#  4   stairhall_                      242 non-null    object
#  5   borough                         242 non-null    object
#  6   house                           242 non-null    object
#  7   street                          242 non-null    object
#  8   address                         242 non-null    object
#  9   city                            242 non-null    object
#  10  state                           242 non-null    object
#  11  zip_code                        242 non-null    object
#  12  bin                             242 non-null    object
#  13  block                           242 non-null    object
#  14  lot                             242 non-null    object
#  15  borough_block_lot               242 non-null    object
#  16  census_tract_2010               242 non-null    object
#  17  neighborhood_tabulation_area    242 non-null    object
#  18  neighborhood_tabulation_area_1  242 non-null    object
#  19  community_district              242 non-null    object
#  20  city_council_district           242 non-null    object
#  21  state_assembly_district         242 non-null    object
#  22  state_senate_district           242 non-null    object
#  23  us_congressional_district       242 non-null    object
#  24  latitude                        242 non-null    object
#  25  longitude                       242 non-null    object
#  26  privately_managed               16 non-null     object
# dtypes: object(27)
# memory usage: 75.7+ KB

# %%
merged[merged['latitude'].isna()]
# Out:
#                                 development total_population  tds building  \
# 183                       BOSTON ROAD PLAZA              255  NaN      NaN
# 184                            BOSTON SECOR            1,182  NaN      NaN
# 708                                DOUGLASS            3,898  NaN      NaN
# 855                     EASTCHESTER GARDENS            1,852  NaN      NaN
# 955                             LA PRECIOSA              NaN  NaN      NaN
# ...                                     ...              ...  ...      ...
# 3153  WASHINGTON HEIGHTS REHAB PHASE IV (D)               60  NaN      NaN
# 3154                     WEEKSVILLE GARDENS              697  NaN      NaN
# 3155                         WILLIAMS PLAZA            1,290  NaN      NaN
# 3156                           WILLIAMSBURG            2,873  NaN      NaN
# 3157                            WISE TOWERS              736  NaN      NaN
#
#      stairhall_ borough house street address city  ...  \
# 183         NaN     NaN   NaN    NaN     NaN  NaN  ...
# 184         NaN     NaN   NaN    NaN     NaN  NaN  ...
# 708         NaN     NaN   NaN    NaN     NaN  NaN  ...
# 855         NaN     NaN   NaN    NaN     NaN  NaN  ...
# 955         NaN     NaN   NaN    NaN     NaN  NaN  ...
# ...         ...     ...   ...    ...     ...  ...  ...
# 3153        NaN     NaN   NaN    NaN     NaN  NaN  ...
# 3154        NaN     NaN   NaN    NaN     NaN  NaN  ...
# 3155        NaN     NaN   NaN    NaN     NaN  NaN  ...
# 3156        NaN     NaN   NaN    NaN     NaN  NaN  ...
# 3157        NaN     NaN   NaN    NaN     NaN  NaN  ...
#
#      neighborhood_tabulation_area neighborhood_tabulation_area_1  \
# 183                           NaN                            NaN
# 184                           NaN                            NaN
# 708                           NaN                            NaN
# 855                           NaN                            NaN
# 955                           NaN                            NaN
# ...                           ...                            ...
# 3153                          NaN                            NaN
# 3154                          NaN                            NaN
# 3155                          NaN                            NaN
# 3156                          NaN                            NaN
# 3157                          NaN                            NaN
#
#      community_district city_council_district state_assembly_district  \
# 183                 NaN                   NaN                     NaN
# 184                 NaN                   NaN                     NaN
# 708                 NaN                   NaN                     NaN
# 855                 NaN                   NaN                     NaN
# 955                 NaN                   NaN                     NaN
# ...                 ...                   ...                     ...
# 3153                NaN                   NaN                     NaN
# 3154                NaN                   NaN                     NaN
# 3155                NaN                   NaN                     NaN
# 3156                NaN                   NaN                     NaN
# 3157                NaN                   NaN                     NaN
#
#      state_senate_district us_congressional_district latitude longitude  \
# 183                    NaN                       NaN      NaN       NaN
# 184                    NaN                       NaN      NaN       NaN
# 708                    NaN                       NaN      NaN       NaN
# 855                    NaN                       NaN      NaN       NaN
# 955                    NaN                       NaN      NaN       NaN
# ...                    ...                       ...      ...       ...
# 3153                   NaN                       NaN      NaN       NaN
# 3154                   NaN                       NaN      NaN       NaN
# 3155                   NaN                       NaN      NaN       NaN
# 3156                   NaN                       NaN      NaN       NaN
# 3157                   NaN                       NaN      NaN       NaN
#
#      privately_managed
# 183                NaN
# 184                NaN
# 708                NaN
# 855                NaN
# 955                NaN
# ...                ...
# 3153               NaN
# 3154               NaN
# 3155               NaN
# 3156               NaN
# 3157               NaN
#
# [104 rows x 27 columns]

# %%
df1[df1.development.str.lower().str.contains('east')]
# Out:
#                               development  tds building stairhall_   borough  \
# 0                  1010 EAST 178TH STREET  180        1        013     BRONX
# 367       BRYANT AVENUE-EAST 174TH STREET  235        1        015     BRONX
# 646      COLLEGE AVENUE-EAST 165TH STREET  236        1        002     BRONX
# 736   EAST 152ND STREET-COURTLANDT AVENUE  237        2        011     BRONX
# 737   EAST 152ND STREET-COURTLANDT AVENUE  237        1        010     BRONX
# ...                                   ...  ...      ...        ...       ...
# 2212                        RED HOOK EAST    4        7        023  BROOKLYN
# 2213                        RED HOOK EAST    4        9        029  BROOKLYN
# 2214                        RED HOOK EAST    4        5        017  BROOKLYN
# 2636      TELLER AVENUE-EAST 166TH STREET  223        1        001     BRONX
# 2740             TWIN PARKS EAST (SITE 9)  287        1        010     BRONX
#
#      house             street                 address      city state  ...  \
# 0     1010  EAST 178TH STREET  1010 EAST 178TH STREET     BRONX    NY  ...
# 367   1705      BRYANT AVENUE      1705 BRYANT AVENUE     BRONX    NY  ...
# 646   1020     COLLEGE AVENUE     1020 COLLEGE AVENUE     BRONX    NY  ...
# 736    370  EAST 153RD STREET   370 EAST 153RD STREET     BRONX    NY  ...
# 737    372  EAST 152ND STREET   372 EAST 152ND STREET     BRONX    NY  ...
# ...    ...                ...                     ...       ...   ...  ...
# 2212   774       HENRY STREET        774 HENRY STREET  BROOKLYN    NY  ...
# 2213   123    LORRAINE STREET     123 LORRAINE STREET  BROOKLYN    NY  ...
# 2214   748       HENRY STREET        748 HENRY STREET  BROOKLYN    NY  ...
# 2636  1100      TELLER AVENUE      1100 TELLER AVENUE     BRONX    NY  ...
# 2740  2070     CLINTON AVENUE     2070 CLINTON AVENUE     BRONX    NY  ...
#
#      neighborhood_tabulation_area  \
# 0                          BX0601
# 367                        BX0303
# 646                        BX0401
# 736                        BX0102
# 737                        BX0102
# ...                           ...
# 2212                       BK0601
# 2213                       BK0601
# 2214                       BK0601
# 2636                       BX0401
# 2740                       BX0602
#
#                     neighborhood_tabulation_area_1 community_district  \
# 0                                       West Farms                  6
# 367                              Crotona Park East                  3
# 646                    Concourse-Concourse Village                  4
# 736                                        Melrose                  1
# 737                                        Melrose                  1
# ...                                            ...                ...
# 2212  Carroll Gardens-Cobble Hill-Gowanus-Red Hook                  6
# 2213  Carroll Gardens-Cobble Hill-Gowanus-Red Hook                  6
# 2214  Carroll Gardens-Cobble Hill-Gowanus-Red Hook                  6
# 2636                   Concourse-Concourse Village                  4
# 2740                                       Tremont                  6
#
#      city_council_district state_assembly_district state_senate_district  \
# 0                       15                      87                    32
# 367                     17                      79                    32
# 646                     16                      77                    32
# 736                     17                      84                    29
# 737                     17                      84                    29
# ...                    ...                     ...                   ...
# 2212                    38                      51                    26
# 2213                    38                      51                    26
# 2214                    38                      51                    26
# 2636                    16                      77                    32
# 2740                    15                      79                    32
#
#      us_congressional_district   latitude   longitude privately_managed
# 0                           15  40.840795  -73.880298               NaN
# 367                         14  40.835934  -73.885745               YES
# 646                         15  40.829265  -73.915109               NaN
# 736                         15  40.818853  -73.917644               NaN
# 737                         15  40.818140  -73.917880               NaN
# ...                        ...        ...         ...               ...
# 2212                        10  40.675198  -74.004683               NaN
# 2213                        10  40.675198  -74.004683               NaN
# 2214                        10  40.675198  -74.004683               NaN
# 2636                        15  40.830031  -73.912611               NaN
# 2740                        15  40.846997  -73.887657               NaN
#
# [217 rows x 26 columns]
